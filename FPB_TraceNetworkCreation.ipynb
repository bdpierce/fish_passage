# %% [markdown]
# # Data prep and the creation of a trace network
#
# The purpose of this notebook is to explore generating code to create a trace network with cleaned data layers suitable for use in a fish passage barrier analysis.

# %% [markdown]
# To add:
# - keep only culverts and gravity mains that carry the stream silly!
# - keep on wdfw barriers that are actually barriers
# - get the pipe inlet and outlet points and clip those too
#
# Next steps
# - snap everything together
# - build a trace network
# - see what needs to happen to add the flow direction numbers
# - add the python script as a toolbox
# - test it on the subset!

# %% [markdown]
# ## Create a smaller dataset to test
# (In future, just create copies of the full layers to be used)
#
# **Notes:**
# **- Select the subbasin from SD_Basin that you want to clip to.**
# **- Running this script will overwrite existing clips with the same name.**

# %%
# %%time
# Clip all layers to get a smaller dataset to test with

# Natural fish passage barriers
arcpy.analysis.PairwiseClip(
    in_features="Natural Fish Passage Barriers",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\NaturalBarriers_Clip",
    cluster_tolerance=None
)

# WDFW barriers
arcpy.analysis.PairwiseClip(
    in_features="WDFW_FishPassageSite",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\WDFWBarriers_Clip",
    cluster_tolerance=None
)

# Weirs
arcpy.analysis.PairwiseClip(
    in_features="Utilities.UTIL.swWeirStructure",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\swWeirStructure_Clip",
    cluster_tolerance=None
)

# Streams
arcpy.analysis.PairwiseClip(
    in_features="Utilities.UTIL.envStreams",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\envStreams_Clip",
    cluster_tolerance=None
)

# Gravity mains
arcpy.analysis.PairwiseClip(
    in_features="Utilities.UTIL.swGravityMain",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\swGravityMain_Clip",
    cluster_tolerance=None
)

# Culverts
arcpy.analysis.PairwiseClip(
    in_features="Utilities.UTIL.swCulvert",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\swBasin_Clip",
    cluster_tolerance=None
)
# Out:
# CPU times: total: 1min 22s
# Wall time: 1min 50s
# <Result 'V:\\UtilitiesDeptGIS\\ArcGIS\\Watershed Planning Team\\Environmental Monitoring\\Fish Passage Barriers\\Fish Passage Barriers\\Fish Passage Barriers.gdb\\swBasin_Clip'>

# %%
# Create a trace network
