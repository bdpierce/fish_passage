# %% [markdown]
# # Data prep and the creation of a trace network
#
# The purpose of this notebook is to explore generating code to create a trace network with cleaned data layers suitable for use in a fish passage barrier analysis.

# %% [markdown]
# ## Create a smaller dataset to test
# (In future, just create copies of the full layers to be used)

# %%
# Clip all layers to get a smaller dataset to test with
# I did a batch clip with Lewis Creek Subbasin selected to clip to that region.

arcpy.ImportToolbox(r"C:\Users\bpierce\AppData\Local\Temp\2\ArcGISProTemp21172\Tmp.atbx")
arcpy.Tmp.BatchClip(
    in_features="Utilities.UTIL.envStreams;Utilities.UTIL.swCulvert;Utilities.UTIL.swGravityMain;Utilities.UTIL.swWeirStructure;WDFW_FishPassageSite",
    clip_features="Utilities.UTIL.SD_Basin",
    out_feature_class=r"V:\UtilitiesDeptGIS\ArcGIS\Watershed Planning Team\Environmental Monitoring\Fish Passage Barriers\Fish Passage Barriers\Fish Passage Barriers.gdb\Clip_Lewis_%Name%",
    cluster_tolerance=None
)
